# %% [markdown]
# <a href="https://colab.research.google.com/github/azario0/googlecolab-tests/blob/main/DataFrames.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd

# %%
np.random.seed(48)
mydata = np.random.randint(0,101,(4,3))

# %%
mydata
# Out:
# array([[ 0, 51, 81],
#        [68, 91, 48],
#        [64, 70, 70],
#        [34, 92, 80]])

# %%
myindex = ["CA","NY","AZ","TX"]

# %%
mycolumns = ["Jan","Feb","Mar"]

# %%
df = pd.DataFrame(mydata,index=myindex,columns=mycolumns)

# %%
df
# Out:
#     Jan  Feb  Mar
# CA    0   51   81
# NY   68   91   48
# AZ   64   70   70
# TX   34   92   80

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, CA to TX
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Jan     4 non-null      int64
#  1   Feb     4 non-null      int64
#  2   Mar     4 non-null      int64
# dtypes: int64(3)
# memory usage: 128.0+ bytes

# %%
df = pd.read_csv("/content/sample_data/california_housing_test.csv")

# %%
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3000, step=1)

# %%
df.head(1)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0

# %%
df.tail()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB

# %%
df.describe()
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...

# %%
df.describe().transpose()
# Out:
#                      count           mean            std         min  \
# longitude           3000.0    -119.589200       1.994936   -124.1800
# latitude            3000.0      35.635390       2.129670     32.5600
# housing_median_age  3000.0      28.845333      12.555396      1.0000
# total_rooms         3000.0    2599.578667    2155.593332      6.0000
# total_bedrooms      3000.0     529.950667     415.654368      2.0000
# population          3000.0    1402.798667    1030.543012      5.0000
# households          3000.0     489.912000     365.422710      2.0000
# median_income       3000.0       3.807272       1.854512      0.4999
# median_house_value  3000.0  205846.275000  113119.687470  22500.0000
#
#                            25%           50%            75%          max
# longitude             -121.810    -118.48500    -118.020000    -114.4900
# latitude                33.930      34.27000      37.690000      41.9200
# ...

# %% [markdown]
# ### **Columns**

# %%
type(df["population"])
# Out:
# pandas.core.series.Series

# %%
mycols = ["total_rooms","latitude"]
df[mycols]
# Out:
#       total_rooms  latitude
# 0          3885.0     37.37
# 1          1510.0     34.26
# 2          3589.0     33.78
# 3            67.0     33.82
# 4          1241.0     36.33
# ...           ...       ...
# 2995       1450.0     34.42
# 2996       5257.0     34.06
# 2997        956.0     36.30
# 2998         96.0     34.10
# 2999       1765.0     34.42
#
# [3000 rows x 2 columns]

# %%
df["rooms_lat"]=100 * df["total_rooms"]/df["latitude"]

# %%
df.keys()
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'rooms_lat'],
#       dtype='object')

# %%
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
# ...

# %%
df["rooms_lat"]=np.round(df["rooms_lat"])

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value  rooms_lat
# 0      1537.0       606.0         6.6085            344700.0    10396.0
# 1       809.0       277.0         3.5990            176500.0     4407.0
# 2      1484.0       495.0         5.7934            270500.0    10625.0
# 3        49.0        11.0         6.1359            330000.0      198.0
# 4       850.0       237.0         2.9375             81700.0     3416.0

# %%
df.drop("rooms_lat",axis=1)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df = df.drop("rooms_lat",axis=1)

# %%
df.shape[0]
# Out:
# 3000

# %%
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3000, step=1)

# %%
df = df.set_index('latitude')

# %%
df
# Out:
#           longitude  housing_median_age  total_rooms  total_bedrooms  \
# latitude
# 37.37       -122.05                27.0       3885.0           661.0
# 34.26       -118.30                43.0       1510.0           310.0
# 33.78       -117.81                27.0       3589.0           507.0
# 33.82       -118.36                28.0         67.0            15.0
# 36.33       -119.67                19.0       1241.0           244.0
# ...             ...                 ...          ...             ...
# 34.42       -119.86                23.0       1450.0           642.0
# 34.06       -118.14                27.0       5257.0          1082.0
# 36.30       -119.70                10.0        956.0           201.0
# 34.10       -117.12                40.0         96.0            14.0
# 34.42       -119.63                42.0       1765.0           263.0
#
#           population  households  median_income  median_house_value
# latitude
# ...

# %%
df.reset_index()
# Out:
#       latitude  longitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        37.37    -122.05                27.0       3885.0           661.0
# 1        34.26    -118.30                43.0       1510.0           310.0
# 2        33.78    -117.81                27.0       3589.0           507.0
# 3        33.82    -118.36                28.0         67.0            15.0
# 4        36.33    -119.67                19.0       1241.0           244.0
# ...        ...        ...                 ...          ...             ...
# 2995     34.42    -119.86                23.0       1450.0           642.0
# 2996     34.06    -118.14                27.0       5257.0          1082.0
# 2997     36.30    -119.70                10.0        956.0           201.0
# 2998     34.10    -117.12                40.0         96.0            14.0
# 2999     34.42    -119.63                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df
# Out:
#           longitude  housing_median_age  total_rooms  total_bedrooms  \
# latitude
# 37.37       -122.05                27.0       3885.0           661.0
# 34.26       -118.30                43.0       1510.0           310.0
# 33.78       -117.81                27.0       3589.0           507.0
# 33.82       -118.36                28.0         67.0            15.0
# 36.33       -119.67                19.0       1241.0           244.0
# ...             ...                 ...          ...             ...
# 34.42       -119.86                23.0       1450.0           642.0
# 34.06       -118.14                27.0       5257.0          1082.0
# 36.30       -119.70                10.0        956.0           201.0
# 34.10       -117.12                40.0         96.0            14.0
# 34.42       -119.63                42.0       1765.0           263.0
#
#           population  households  median_income  median_house_value
# latitude
# ...

# %%
df=df.reset_index()

# %%
df
# Out:
#       latitude  longitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        37.37    -122.05                27.0       3885.0           661.0
# 1        34.26    -118.30                43.0       1510.0           310.0
# 2        33.78    -117.81                27.0       3589.0           507.0
# 3        33.82    -118.36                28.0         67.0            15.0
# 4        36.33    -119.67                19.0       1241.0           244.0
# ...        ...        ...                 ...          ...             ...
# 2995     34.42    -119.86                23.0       1450.0           642.0
# 2996     34.06    -118.14                27.0       5257.0          1082.0
# 2997     36.30    -119.70                10.0        956.0           201.0
# 2998     34.10    -117.12                40.0         96.0            14.0
# 2999     34.42    -119.63                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df=df.set_index("latitude")

# %%
df
# Out:
#           longitude  housing_median_age  total_rooms  total_bedrooms  \
# latitude
# 37.37       -122.05                27.0       3885.0           661.0
# 34.26       -118.30                43.0       1510.0           310.0
# 33.78       -117.81                27.0       3589.0           507.0
# 33.82       -118.36                28.0         67.0            15.0
# 36.33       -119.67                19.0       1241.0           244.0
# ...             ...                 ...          ...             ...
# 34.42       -119.86                23.0       1450.0           642.0
# 34.06       -118.14                27.0       5257.0          1082.0
# 36.30       -119.70                10.0        956.0           201.0
# 34.10       -117.12                40.0         96.0            14.0
# 34.42       -119.63                42.0       1765.0           263.0
#
#           population  households  median_income  median_house_value
# latitude
# ...

# %%
df.iloc[0]
# Out:
# longitude               -122.0500
# housing_median_age        27.0000
# total_rooms             3885.0000
# total_bedrooms           661.0000
# population              1537.0000
# households               606.0000
# median_income              6.6085
# median_house_value    344700.0000
# Name: 37.37, dtype: float64

# %%
df.loc[37.37]
# Out:
#           longitude  housing_median_age  total_rooms  total_bedrooms  \
# latitude
# 37.37       -122.05                27.0       3885.0           661.0
# 37.37       -121.88                14.0       6016.0          1404.0
# 37.37       -122.13                30.0       2139.0           260.0
# 37.37       -121.81                26.0       2987.0           539.0
# 37.37       -122.12                37.0       1446.0           181.0
# 37.37       -122.11                49.0       1068.0           190.0
# 37.37       -121.98                35.0        995.0           202.0
# 37.37       -121.95                39.0        446.0           129.0
# 37.37       -120.50                18.0       8606.0          1678.0
# 37.37       -121.83                43.0       1461.0           284.0
#
#           population  households  median_income  median_house_value
# latitude
# 37.37         1537.0       606.0         6.6085            344700.0
# ...

# %%
s = df.iloc[0:4]
s
# Out:
#           longitude  housing_median_age  total_rooms  total_bedrooms  \
# latitude
# 37.37       -122.05                27.0       3885.0           661.0
# 34.26       -118.30                43.0       1510.0           310.0
# 33.78       -117.81                27.0       3589.0           507.0
# 33.82       -118.36                28.0         67.0            15.0
#
#           population  households  median_income  median_house_value
# latitude
# 37.37         1537.0       606.0         6.6085            344700.0
# 34.26          809.0       277.0         3.5990            176500.0
# 33.78         1484.0       495.0         5.7934            270500.0
# 33.82           49.0        11.0         6.1359            330000.0

# %%
df.drop(37.37,axis=0)
# Out:
#           longitude  housing_median_age  total_rooms  total_bedrooms  \
# latitude
# 34.26       -118.30                43.0       1510.0           310.0
# 33.78       -117.81                27.0       3589.0           507.0
# 33.82       -118.36                28.0         67.0            15.0
# 36.33       -119.67                19.0       1241.0           244.0
# 36.51       -119.56                37.0       1018.0           213.0
# ...             ...                 ...          ...             ...
# 34.42       -119.86                23.0       1450.0           642.0
# 34.06       -118.14                27.0       5257.0          1082.0
# 36.30       -119.70                10.0        956.0           201.0
# 34.10       -117.12                40.0         96.0            14.0
# 34.42       -119.63                42.0       1765.0           263.0
#
#           population  households  median_income  median_house_value
# latitude
# ...

# %%
df.head()
# Out:
#           longitude  housing_median_age  total_rooms  total_bedrooms  \
# latitude
# 37.37       -122.05                27.0       3885.0           661.0
# 34.26       -118.30                43.0       1510.0           310.0
# 33.78       -117.81                27.0       3589.0           507.0
# 33.82       -118.36                28.0         67.0            15.0
# 36.33       -119.67                19.0       1241.0           244.0
#
#           population  households  median_income  median_house_value
# latitude
# 37.37         1537.0       606.0         6.6085            344700.0
# 34.26          809.0       277.0         3.5990            176500.0
# 33.78         1484.0       495.0         5.7934            270500.0
# 33.82           49.0        11.0         6.1359            330000.0
# 36.33          850.0       237.0         2.9375             81700.0

# %%
s=df.loc[37.37]
s
# Out:
#           longitude  housing_median_age  total_rooms  total_bedrooms  \
# latitude
# 37.37       -122.05                27.0       3885.0           661.0
# 37.37       -121.88                14.0       6016.0          1404.0
# 37.37       -122.13                30.0       2139.0           260.0
# 37.37       -121.81                26.0       2987.0           539.0
# 37.37       -122.12                37.0       1446.0           181.0
# 37.37       -122.11                49.0       1068.0           190.0
# 37.37       -121.98                35.0        995.0           202.0
# 37.37       -121.95                39.0        446.0           129.0
# 37.37       -120.50                18.0       8606.0          1678.0
# 37.37       -121.83                43.0       1461.0           284.0
#
#           population  households  median_income  median_house_value
# latitude
# 37.37         1537.0       606.0         6.6085            344700.0
# ...

# %%
s = s * 0
s
# Out:
#           longitude  housing_median_age  total_rooms  total_bedrooms  \
# latitude
# 37.37          -0.0                 0.0          0.0             0.0
# 37.37          -0.0                 0.0          0.0             0.0
# 37.37          -0.0                 0.0          0.0             0.0
# 37.37          -0.0                 0.0          0.0             0.0
# 37.37          -0.0                 0.0          0.0             0.0
# 37.37          -0.0                 0.0          0.0             0.0
# 37.37          -0.0                 0.0          0.0             0.0
# 37.37          -0.0                 0.0          0.0             0.0
# 37.37          -0.0                 0.0          0.0             0.0
# 37.37          -0.0                 0.0          0.0             0.0
#
#           population  households  median_income  median_house_value
# latitude
# 37.37            0.0         0.0            0.0                 0.0
# ...

# %%
df.loc[37.37]
# Out:
#           longitude  housing_median_age  total_rooms  total_bedrooms  \
# latitude
# 37.37       -122.05                27.0       3885.0           661.0
# 37.37       -121.88                14.0       6016.0          1404.0
# 37.37       -122.13                30.0       2139.0           260.0
# 37.37       -121.81                26.0       2987.0           539.0
# 37.37       -122.12                37.0       1446.0           181.0
# 37.37       -122.11                49.0       1068.0           190.0
# 37.37       -121.98                35.0        995.0           202.0
# 37.37       -121.95                39.0        446.0           129.0
# 37.37       -120.50                18.0       8606.0          1678.0
# 37.37       -121.83                43.0       1461.0           284.0
#
#           population  households  median_income  median_house_value
# latitude
# 37.37         1537.0       606.0         6.6085            344700.0
# ...
